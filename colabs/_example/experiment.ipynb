# %% [markdown]
# # Experiment title
#
# Standalone Colab checked into `colabs/<experiment-id>/`.
#
# **Question:** …

# %%
# Optional deps
# %pip install -q numpy
print("ok — replace this cell with the experiment")
